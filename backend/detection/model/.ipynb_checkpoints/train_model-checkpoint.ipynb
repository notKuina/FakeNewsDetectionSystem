# %% [markdown]
# import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv('../data/Fake.csv')
true = pd.read_csv('../data/True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
import pandas as pd
df = pd.read_csv("../data/True.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
paragraphs = (df["title"].fillna('') + "." + df["text"].fillna('')).tolist()

# %%
full_paragraph = " ".join(paragraphs)

# %%
with open("real_news_paragraph.txt", "w", encoding= "utf-8") as f:f.write(full_paragraph)

# %%
fake['class']=0
true['class']=1

# %%
data = pd.concat([fake,true], axis = 0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 21179  FBI POSTS $5,000 REWARD For Person Who Committ...
# 17002  Outrageous! Apparently $68 Billion Isn’t Enoug...
# 18654  Moscow denies Ukraine's accusation that it lef...
# 8978   British EU exit a model for Trump's campaign, ...
# 454     Ex-DOJ Lawyer Just Dropped The Most Depressin...
# 12581      Pictures of the Year: A picture and its story
# 1606    Plane Passengers Get Into ALL OUT BRAWL, Then...
# 21311  SAY WHAT? Obama Gives Go Ahead For New UN “Reg...
# 19737  WOW! Hillary’s VP Pick Tim Kaine Gets Only 30 ...
# 9046   Federal judges question intent behind North Ca...
#
#                                                     text          subject  \
# 21179  Americans were warned by Attorney General, Lor...        left-news
# 17002  Does anyone else see the lunacy in this? You h...  Government News
# 18654  MOSCOW (Reuters) - Russian troops that took pa...        worldnews
# 8978   TURNBERRY, Scotland (Reuters) - U.S. president...     politicsNews
# 454    While most Americans are aware that Donald Tru...             News
# 12581  (Reuters) - Reuters photographers witnessed th...        worldnews
# 1606   Yet another altercation has erupted on board a...             News
# 21311  If seven years ago, someone told Americans tha...        left-news
# 19737  BREAKING: #TimKaine rally only about 30 people...        left-news
# 9046   WASHINGTON (Reuters) - Federal appeals court j...     politicsNews
#
#                       date  class
# 21179         Dec 31, 2015      0
# 17002         Oct 26, 2015      0
# 18654  September 30, 2017       1
# 8978        June 24, 2016       1
# 454      September 1, 2017      0
# 12581   December 11, 2017       1
# 1606           May 2, 2017      0
# 21311         Nov 20, 2015      0
# 19737         Oct 25, 2016      0
# 9046        June 21, 2016       1

# %%
data = data.drop(["title","subject","date"], axis = 1)

# %% [raw]
# data.reset_index(inplace=True)

# %%
print(data.columns)
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.sample(5)
# Out:
#                                                     text  class
# 18405  Mika is all of a sudden aware of the Trump s m...      0
# 4018   SEOUL (Reuters) - The spokesman for the front ...      1
# 1076   It s hard not to feel that John McCain, after ...      0
# 13095  Wow! This video really shows how the media cov...      0
# 6371   The Panama Papers recently exposed the worst o...      0

# %%
def clean_text(text):
    text = text.lower()  
    text = re.sub(r'\[.*?\]', '', text)  
    text = re.sub(r'\W', ' ', text)  
    text = re.sub(r'https?://\S+|www\.\S+', '', text) 
    text = re.sub(r'<.*?>+', '', text) 
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text) 
    text = re.sub(r'\n', '', text)  
    text = re.sub(r'\w*\d\w*', '', text) 
    return text

# %%
data["text"] = data["text"].apply(clean_text)

# %%
x=data["text"]
y=data["class"]

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test = vectorizer.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(xv_train, ytrain)
# Out:
# LogisticRegression()

# %%
whos
# Out:
# Variable                Type                  Data/Info
# -------------------------------------------------------
# LogisticRegression      type                  <class 'sklearn.linear_mo<...>stic.LogisticRegression'>
# TfidfVectorizer         type                  <class 'sklearn.feature_e<...>on.text.TfidfVectorizer'>
# classification_report   function              <function classification_<...>rt at 0x00000287284FD440>
# clean_text              function              <function clean_text at 0x0000028729482160>
# data                    DataFrame                                      <...>n[44898 rows x 2 columns]
# df                      DataFrame                                      <...>n[21417 rows x 4 columns]
# f                       TextIOWrapper         <_io.TextIOWrapper name='<...>ode='w' encoding='utf-8'>
# fake                    DataFrame                                      <...>n[23481 rows x 5 columns]
# full_paragraph          str                   As U.S. budget fight loom<...>d aviation among others.
# joblib                  module                <module 'joblib' from 'd:<...>es\\joblib\\__init__.py'>
# lr                      LogisticRegression    LogisticRegression()
# paragraphs              list                  n=21417
# pd                      module                <module 'pandas' from 'd:<...>es\\pandas\\__init__.py'>
# re                      module                <module 're' from 'C:\\Us<...>3\\Lib\\re\\__init__.py'>
# string                  module                <module 'string' from 'C:<...>thon313\\Lib\\string.py'>
# train_test_split        function              <function train_test_split at 0x00000287285616C0>
# true                    DataFrame                                      <...>n[21417 rows x 5 columns]
# vectorizer              TfidfVectorizer       TfidfVectorizer()
# x                       Series                0        donald trump jus<...>gth: 44898, dtype: object
# xtest                   Series                22216     century wire sa<...>gth: 11225, dtype: object
# xtrain                  Series                11349    seoul  reuters  <...>gth: 33673, dtype: object
# xv_test                 csr_matrix            <Compressed Sparse Row sp<...>030)	0.030769279751293878
# xv_train                csr_matrix            <Compressed Sparse Row sp<...>1834)	0.11424753723333685
# y                       Series                0        0\n1        0\n2<...>ngth: 44898, dtype: int64
# ytest                   Series                22216    0\n4436     1\n1<...>ngth: 11225, dtype: int64
# ytrain                  Series                11349    1\n6018     0\n1<...>ngth: 33673, dtype: int64

# %%
prediction = lr.predict(xv_test)
print(lr.score(xv_test,ytest))
# Out:
# 0.9858351893095768

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']

# %%
pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in d:\fakenewsdetection\fakenews\venv\lib\site-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (4.13.4)
# Requirement already satisfied: Pillow>=3.3.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (11.2.1)
# Requirement already satisfied: PyYAML>=3.11 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (1.3.0)
# Requirement already satisfied: lxml>=3.6.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (5.4.0)
# Requirement already satisfied: nltk>=3.2.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (2.32.4)
# Requirement already satisfied: feedparser>=5.2.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (5.3.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (2.9.0.post0)
# Requirement already satisfied: tinysegmenter==0.3 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.14.0)
# Requirement already satisfied: six in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Requirement already satisfied: sgmllib3k in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.2.1)
# Requirement already satisfied: joblib in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (2025.6.15)
# Requirement already satisfied: requests-file>=1.4 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.18.0)
# Requirement already satisfied: colorama in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install newspaper3k
# Out:
# Requirement already satisfied: newspaper3k in d:\fakenewsdetection\fakenews\venv\lib\site-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (4.13.4)
# Requirement already satisfied: Pillow>=3.3.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (11.2.1)
# Requirement already satisfied: PyYAML>=3.11 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (1.3.0)
# Requirement already satisfied: lxml>=3.6.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (5.4.0)
# Requirement already satisfied: nltk>=3.2.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (2.32.4)
# Requirement already satisfied: feedparser>=5.2.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (5.3.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (2.9.0.post0)
# Requirement already satisfied: tinysegmenter==0.3 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.14.0)
# Requirement already satisfied: six in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Requirement already satisfied: sgmllib3k in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.2.1)
# Requirement already satisfied: joblib in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from requests>=2.10.0->newspaper3k) (2025.6.15)
# Requirement already satisfied: requests-file>=1.4 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.18.0)
# Requirement already satisfied: colorama in d:\fakenewsdetection\fakenews\venv\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from newspaper import Article

# %%
# import joblib

# model = joblib.load("lr_model.jb")  # or whatever filename you saved it as
# from sklearn.metrics import accuracy_score, classification_report

# X_test_vectorized = vectorizer.transform(X_test)
# y_pred = model.predict(X_test_vectorized)

# print(classification_report(y_test, y_pred))

# %%
print("--- Dataset Shapes ---")
print(f"Original DataFrame shape: {data.shape}")  # or df.shape if you want
print(f"xtrain shape: {xtrain.shape}")
print(f"ytrain shape: {ytrain.shape}")
print(f"xtest shape: {xtest.shape}")
print(f"ytest shape: {ytest.shape}")

# Verify sizes sum correctly
assert (xtrain.shape[0] + xtest.shape[0]) == data.shape[0]
assert (ytrain.shape[0] + ytest.shape[0]) == data.shape[0]
print("Shape check passed!")
# Out:
# --- Dataset Shapes ---
# Original DataFrame shape: (44898, 2)
# xtrain shape: (33673,)
# ytrain shape: (33673,)
# xtest shape: (11225,)
# ytest shape: (11225,)
# Shape check passed!
